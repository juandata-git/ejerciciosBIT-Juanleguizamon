# %%
#4_Genere un nuevo dataset aplicando un ordenamiento sobre los datos originales

print("Ordenado por edad (descendente):")
titanic.sort_values(by=['Edad','Nombre'], ascending=False)
# Out:
# Ordenado por edad (descendente):
#      ID pasajero  Sobrevivió?  Pclass  \
# 630          631            1       1
# 851          852            0       3
# 96            97            0       1
# 493          494            0       1
# 116          117            0       3
# ..           ...          ...     ...
# 507          508            1       1
# 593          594            0       3
# 140          141            0       3
# 598          599            0       3
# 168          169            0       1
#
#                                             Nombre    sexo  Edad  SibSp  \
# 630           Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 851                            Svensson, Mr. Johan    male  74.0      0
# 96                       Goldschmidt, Mr. George B    male  71.0      0
# 493                        Artagaveytia, Mr. Ramon    male  71.0      0
# 116                           Connors, Mr. Patrick    male  70.5      0
# ...

# %%
#3_Genere un nuevo dataset aplicando un filtro sobre los datos originales


titanic = titanic.rename(columns=
 {'Survived':"Sobrevivió?",
  "Age":"Edad","PassengerId":"ID pasajero","Name":"Nombre"
 })
titanic


titanic_filtrado = titanic[titanic["Edad"] > 30]


print (titanic_filtrado.head())
titanic_filtrado.head()
# Out:
#     ID pasajero  Sobrevivió?  Pclass  \
# 1             2            1       1
# 3             4            1       1
# 4             5            0       3
# 6             7            0       1
# 11           12            1       1
#
#                                                Nombre    sexo  Edad  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 4       0    373450   8.0500   NaN        S
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# ...

# %%
# 2. Muestre la forma (SHAPE), información general (df.info()) y estadisticas descriptivas (df.describe()) del dataset
 
df.shape
print("forma del dataset",df.shape)

print("\nInformación general:")
df.info()

print("\Estadísticas descriptivas:")
print(df.describe())
# Out:
# forma del dataset (891, 12)
#
# Información general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# \Estadísticas descriptivas:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# ...

# %%
#1-Leer un archivo del formato de su elección sobre cualquier temática

import pandas as pd

titanic = pd.read_csv(r"C:\Users\juanl\Downloads\Titanic-Dataset.csv")

titanic.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...
