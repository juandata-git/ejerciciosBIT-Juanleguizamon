# %% [markdown]
# <a href="https://colab.research.google.com/github/juandata-git/ejerciciosBIT-Juanleguizamon/blob/main/Actividad_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Importación de Librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN

# %%
# 2. Carga del Dataset
# Asegúrate de subir el archivo a tu entorno de Colab
df = pd.read_csv('/content/spotifydataset.csv')

# %%
print(f"dimesion del dataset: {df.shape}")
df.head()
# Out:
# dimesion del dataset: (1000, 23)
#    Unnamed: 0    artist_name genres  followers  artist_popularity  \
# 0           0  Ariana Grande    pop   98934105                 89
# 1           1  Ariana Grande    pop   98934105                 85
# 2           2  Ariana Grande    pop   98934105                 83
# 3           3  Ariana Grande    pop   98934105                 80
# 4           4  Ariana Grande    pop   98934105                 79
#
#                                           artist_url  \
# 0  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 1  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 2  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 3  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 4  https://open.spotify.com/artist/66CXWjxzNUsdJx...
#
#                                           track_name            album_name  \
# 0           we can't be friends (wait for your love)      eternal sunshine
# 1                                    the boy is mine      eternal sunshine
# 2                           intro (end of the world)      eternal sunshine
# 3  Save Your Tears (Remix) (with Ariana Grande) -...  After Hours (Deluxe)
# 4                                          yes, and?      eternal sunshine
#
#   release_date  duration_ms  ...  energy  key  loudness  mode  speechiness  \
# 0   2024-03-08       228639  ...   0.646    5    -8.334     1       0.0427
# 1   2024-03-08       173639  ...   0.630    7    -5.854     0       0.0434
# 2   2024-03-08        92400  ...   0.362   10    -9.480     1       0.0416
# 3   2020-03-20       191013  ...   0.825    0    -4.645     1       0.0325
# 4   2024-03-08       214994  ...   0.775    1    -6.614     1       0.0548
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.0615          0.000030    0.0740    0.295  115.842
# 1        0.1570          0.000000    0.0732    0.447   97.998
# 2        0.6700          0.000000    0.1760    0.385   84.726
# 3        0.0215          0.000024    0.0936    0.593  118.091
# 4        0.1900          0.000065    0.1130    0.787  118.998
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'genres', 'followers', 'artist_popularity',
#        'artist_url', 'track_name', 'album_name', 'release_date', 'duration_ms',
#        'explicit', 'track_popularity', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
# Selección de Features (Características de Audio)
audio_features = [    'duration_ms',       'explicit', 'track_popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo'
]

X = df[audio_features]

# 3. Escalado de Datos (Estandarización)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Datos escalados correctamente.")
# Out:
# Datos escalados correctamente.

# %%
X
# Out:
#      duration_ms  explicit  track_popularity  danceability  energy  key  \
# 0         228639     False                89         0.645   0.646    5
# 1         173639      True                85         0.795   0.630    7
# 2          92400      True                83         0.506   0.362   10
# 3         191013     False                80         0.650   0.825    0
# 4         214994      True                79         0.787   0.775    1
# ..           ...       ...               ...           ...     ...  ...
# 995       369573      True                69         0.751   0.708    0
# 996       324373      True                64         0.792   0.701    6
# 997       304226      True                60         0.746   0.978    9
# 998       222653      True                59         0.749   0.856    2
# 999       261266      True                58         0.857   0.764    1
#
#      loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0      -8.334     1       0.0427        0.0615          0.000030    0.0740
# 1      -5.854     0       0.0434        0.1570          0.000000    0.0732
# 2      -9.480     1       0.0416        0.6700          0.000000    0.1760
# 3      -4.645     1       0.0325        0.0215          0.000024    0.0936
# 4      -6.614     1       0.0548        0.1900          0.000065    0.1130
# ..        ...   ...          ...           ...               ...       ...
# 995    -5.653     1       0.0545        0.0482          0.000018    0.1070
# 996    -7.198     0       0.2830        0.1050          0.000000    0.7610
# 997    -5.324     1       0.0978        0.0555          0.000041    0.0260
# 998    -5.833     1       0.2350        0.1070          0.000000    0.7450
# 999    -6.304     1       0.2460        0.0398          0.000000    0.4250
#
#      valence    tempo
# 0      0.295  115.842
# 1      0.447   97.998
# 2      0.385   84.726
# 3      0.593  118.091
# 4      0.787  118.998
# ..       ...      ...
# 995    0.509  108.970
# 996    0.251  103.890
# 997    0.653  153.809
# 998    0.402  103.773
# 999    0.578   93.071
#
# [1000 rows x 14 columns]

# %%
pd.DataFrame(X_scaled)
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.247746 -0.534179  1.238679  0.200823 -0.070192 -0.067277 -0.262122
# 1   -0.589729  1.872032  1.071126  1.098154 -0.147313  0.486445  0.291770
# 2   -1.826740  1.872032  0.987349 -0.630704 -1.439104  1.317029 -0.518074
# 3   -0.325178 -0.534179  0.861684  0.230734  0.792609 -1.451583  0.561793
# 4    0.039976  1.872032  0.819796  1.050296  0.551603 -1.174722  0.122029
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  2.393722  1.872032  0.400913  0.834937  0.228655 -1.451583  0.336662
# 996  1.705470  1.872032  0.191471  1.080207  0.194915  0.209584 -0.008404
# 997  1.398695  1.872032  0.023918  0.805026  1.530086  1.040168  0.410143
# 998  0.156598  1.872032 -0.017970  0.822972  0.942032 -0.897861  0.296461
# 999  0.744551  1.872032 -0.059858  1.469051  0.498582 -1.174722  0.191266
#
#            7         8         9         10        11        12        13
# 0    0.794557 -0.538762 -0.707668 -0.331336 -0.789715 -0.952150 -0.224734
# 1   -1.258562 -0.531018 -0.376933 -0.331471 -0.795218 -0.299172 -0.861119
# 2    0.794557 -0.550930  1.399684 -0.331471 -0.088114 -0.565518 -1.334449
# 3    0.794557 -0.651599 -0.846195 -0.331363 -0.654898  0.328030 -0.144526
# 4    0.794557 -0.404905 -0.262648 -0.331181 -0.521456  1.161436 -0.112179
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.794557 -0.408224 -0.753728 -0.331389 -0.562726 -0.032826 -0.469815
# 996 -1.258562  2.119558 -0.557019 -0.331471  3.935778 -1.141169 -0.650988
# 997  0.794557  0.070782 -0.728447 -0.331289 -1.119881  0.585784  1.129314
# 998  0.794557  1.588558 -0.550093 -0.331471  3.825723 -0.492488 -0.655160
# 999  0.794557  1.710245 -0.782819 -0.331471  1.624620  0.263592 -1.036834
#
# [1000 rows x 14 columns]

# %%
# Aplicamos PCA para reducir a 2 componentes
pca = PCA(n_components=2)

# %%
scattered_data = pca.fit_transform(X_scaled)
plt.scatter(scattered_data[:, 0], scattered_data[:, 1])
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.title('Datos Reducidos a 2 Componentes')
plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.21723524, 0.12552635])

# %%
pca.components_
# Out:
# array([[-0.07620375,  0.14926916,  0.17596678,  0.27690632,  0.45494091,
#          0.03206652,  0.48330277, -0.06522716,  0.12657501, -0.41028226,
#         -0.38238872,  0.13088911,  0.25477347,  0.07628407],
#        [-0.3735646 ,  0.37282499,  0.12252041,  0.43480276, -0.31621231,
#          0.07334386, -0.20318619, -0.16595643,  0.31099381,  0.27122493,
#         -0.1142876 , -0.18157435,  0.28068855, -0.21930241]])

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X_scaled)
kmeans.labels_

plt.scatter(scattered_data[:, 0], scattered_data[:, 1], c=kmeans.labels_)
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.title('Datos Reducidos a 2 Componentes')
plt.show()

# %%
## Elbow method
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
db = DBSCAN(eps=2.8, min_samples=3)
db.fit(X_scaled)
db.labels_

plt.scatter(scattered_data[:, 0], scattered_data[:, 1], c=db.labels_)
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
# Out:
# Text(0, 0.5, 'Componente Principal 2')

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

neighbors = NearestNeighbors(n_neighbors=5)
neighbors_fit = neighbors.fit(X_scaled)
distances, indices = neighbors_fit.kneighbors(X_scaled)
distances = np.sort(distances[:, 1])  # distancia al 2NDO vecino

plt.plot(distances)
plt.title('Gráfico de k-distancia para estimar eps')
plt.xlabel('Puntos ordenados')
plt.ylabel('Distancia al 5nto vecino')
plt.grid()
plt.show()

# %%
df['cluster'] = kmeans.labels_
df.head()
# Out:
#    Unnamed: 0    artist_name genres  followers  artist_popularity  \
# 0           0  Ariana Grande    pop   98934105                 89
# 1           1  Ariana Grande    pop   98934105                 85
# 2           2  Ariana Grande    pop   98934105                 83
# 3           3  Ariana Grande    pop   98934105                 80
# 4           4  Ariana Grande    pop   98934105                 79
#
#                                           artist_url  \
# 0  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 1  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 2  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 3  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 4  https://open.spotify.com/artist/66CXWjxzNUsdJx...
#
#                                           track_name            album_name  \
# 0           we can't be friends (wait for your love)      eternal sunshine
# 1                                    the boy is mine      eternal sunshine
# 2                           intro (end of the world)      eternal sunshine
# 3  Save Your Tears (Remix) (with Ariana Grande) -...  After Hours (Deluxe)
# 4                                          yes, and?      eternal sunshine
#
#   release_date  duration_ms  ...  key  loudness  mode  speechiness  \
# 0   2024-03-08       228639  ...    5    -8.334     1       0.0427
# 1   2024-03-08       173639  ...    7    -5.854     0       0.0434
# 2   2024-03-08        92400  ...   10    -9.480     1       0.0416
# 3   2020-03-20       191013  ...    0    -4.645     1       0.0325
# 4   2024-03-08       214994  ...    1    -6.614     1       0.0548
#
#    acousticness  instrumentalness  liveness  valence    tempo  cluster
# 0        0.0615          0.000030    0.0740    0.295  115.842        1
# 1        0.1570          0.000000    0.0732    0.447   97.998        6
# 2        0.6700          0.000000    0.1760    0.385   84.726        2
# 3        0.0215          0.000024    0.0936    0.593  118.091        1
# 4        0.1900          0.000065    0.1130    0.787  118.998        6
#
# [5 rows x 24 columns]

# %%
df.groupby('cluster').count()['artist_url']
# Out:
# cluster
# 0     65
# 1    172
# 2     94
# 3     87
# 4    181
# 5     39
# 6    147
# 7    127
# 8     36
# 9     52
# Name: artist_url, dtype: int64

# %%
df_cluster = df.groupby('cluster')[audio_features].mean()
df_cluster
# Out:
#            duration_ms  explicit  track_popularity  danceability    energy  \
# cluster
# 0        230930.276923  0.046154          3.969231      0.613185  0.680308
# 1        206842.215116  0.000000         69.732558      0.694500  0.687192
# 2        208926.393617  0.042553         61.893617      0.486713  0.371065
# 3        215337.057471  0.241379         64.310345      0.573414  0.846678
# 4        202852.668508  0.000000         68.961326      0.686227  0.714961
# 5        274007.692308  0.025641         20.794872      0.556513  0.691795
# 6        202080.040816  1.000000         69.945578      0.726245  0.674027
# 7        236307.874016  0.055118         65.118110      0.453016  0.772827
# 8        221564.388889  0.000000         48.333333      0.335750  0.163393
# 9        159847.461538  0.750000         41.903846      0.657538  0.578904
#
#               key   loudness      mode  speechiness  acousticness  \
# cluster
# 0        4.476923  -6.844431  0.661538     0.091511      0.208527
# 1        5.034884  -6.296320  1.000000     0.064349      0.213700
# 2        5.734043 -10.223447  0.840426     0.041643      0.721862
# 3        4.609195  -4.743264  0.758621     0.093907      0.097320
# 4        5.983425  -5.660182  0.000000     0.072127      0.213760
# 5        5.205128  -8.644282  0.615385     0.061695      0.215054
# 6        5.326531  -6.146735  0.537415     0.115739      0.187264
# 7        5.196850  -5.519567  0.803150     0.071402      0.090109
# 8        4.500000 -23.017139  0.638889     0.049047      0.953833
# 9        4.903846  -8.924192  0.480769     0.365242      0.361920
#
#          instrumentalness  liveness   valence       tempo
# cluster
# 0                0.031134  0.154995  0.469140  128.243600
# 1                0.000664  0.142115  0.662919  115.109308
# 2                0.033148  0.147485  0.335745  112.631872
# 3                0.018509  0.496759  0.590253  130.948356
# 4                0.005176  0.162644  0.614164  117.621039
# 5                0.813128  0.197244  0.377956  127.142538
# 6                0.006109  0.161033  0.538971  119.012673
# 7                0.027808  0.168172  0.353208  140.580961
# 8                0.835056  0.120872  0.282114  111.575333
# 9                0.013378  0.205729  0.558981  123.376654

# %%
df[df['cluster']==1]['genres'].value_counts()
# Out:
# genres
# pop                                                                                                    9
# banda, musica mexicana, norteno                                                                        7
# country                                                                                                7
# neo mellow, post-teen pop, viral pop                                                                   7
# atl hip hop, contemporary r&b, dance pop, pop, r&b, rap, south carolina hip hop, urban contemporary    6
# banda, corrido, musica mexicana, norteno, sad sierreno, sierreno                                       6
# desi hip hop, filmi, tamil hip hop                                                                     6
# pop, singer-songwriter pop, uk pop                                                                     5
# dance pop, pop                                                                                         5
# dembow, rap dominicano, trap latino, urbano latino                                                     5
# bachata, bachata dominicana, latin hip hop, latin pop, tropical, urbano latino                         5
# k-pop girl group                                                                                       5
# trap boricua, urbano latino                                                                            5
# album rock, classic rock, folk rock, mellow gold, soft rock                                            5
# electropop, etherpop, indie poptimism, pop                                                             4
# escape room, hip hop, indie soul, neo soul                                                             4
# bachata, latin hip hop, latin pop, urbano latino                                                       4
# pov: indie                                                                                             4
# dance pop, edm, pop, pop dance                                                                         3
# europop, swedish pop                                                                                   3
# canadian pop, canadian singer-songwriter, lilith, neo mellow, pop rock, singer-songwriter              3
# british soul, neo soul                                                                                 3
# filmi, modern bollywood                                                                                3
# afrobeats                                                                                              3
# contemporary country, country, country road, country rock                                              3
# electro house, pop nacional, slap house                                                                3
# dance pop, pop, r&b, urban contemporary                                                                3
# contemporary r&b, dance pop, hip pop, r&b, urban contemporary                                          2
# canadian contemporary r&b, canadian pop, pop                                                           2
# dance pop, girl group, post-teen pop                                                                   2
# social media pop                                                                                       2
# reggaeton, reggaeton flow, trap boricua, trap latino, urbano latino                                    2
# garage rock, modern rock, permanent wave, rock, sheffield indie                                        2
# big room, dance pop, dutch house, edm, electro house, pop dance, progressive electro house             2
# dance pop, edm, pop, pop dance, progressive electro house                                              2
# album rock, classic rock, hard rock, rock                                                              2
# contemporary country, modern country pop                                                               2
# gen z singer-songwriter, singer-songwriter pop                                                         2
# afrobeats, nigerian pop                                                                                2
# alternative metal, metalcore, neon pop punk, pop punk, screamo                                         1
# neo soul, pop, r&b                                                                                     1
# australian rock, hard rock, rock                                                                       1
# canadian pop, candy pop, dance pop, pop                                                                1
# melodic rap, rap, trap                                                                                 1
# alternative metal, alternative rock, grunge, hard rock, nu metal, rock                                 1
# british soul, pop, pop soul, uk pop                                                                    1
# alt z, pop, pov: indie                                                                                 1
# funk pop, funk rj, pagode baiano, pop, pop nacional                                                    1
# electro house                                                                                          1
# art pop, chamber pop, dream pop, dreamo, indie pop, indie rock, noise pop, shoegaze, toronto indie     1
# puerto rican pop, reggaeton, trap latino, urbano latino                                                1
# k-rap                                                                                                  1
# alternative metal, modern rock, neo mellow, neon pop punk, pop punk, pop rock, post-grunge             1
# dutch house, dutch trance, edm, pop dance, progressive house, trance                                   1
# alt z                                                                                                  1
# Name: count, dtype: int64

# %%
df[df['cluster']==1]['artist_name'].value_counts()
# Out:
# artist_name
# Alan Jackson                                     7
# La Arrolladora Banda El Limón De Rene Camacho    7
# Andy Grammer                                     7
# USHER                                            6
# Alfredo Olivas                                   6
#                                                 ..
# Rauw Alejandro                                   1
# Agust D                                          1
# The All-American Rejects                         1
# Armin van Buuren                                 1
# Gracie Abrams                                    1
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# ❓ Preguntas de Cierre
# Basado en el Heatmap, ¿qué tipo de canciones (tristes, bailables, acústicas) predominan en los diferentes Clusters?
#
# -segun el cluster al tipo de canciones predominan:
# 1- pop
# 2- musica de banda/ norteña
# 3-contry
#
# Al incluir la información de artistas, que artistas estan en un mismo cluster? Coincide esto con su genero musical habitual?
#
# -realizando un cluster sobre los artistas son
#
# 1-Alan Jackson- musica contry
# 2-La Arrolladora Banda El Limón De Rene Camacho - musica de banda
# 3-Andy Grammer- musica pop
#
#
# y si estan en el ranking tres ya lo que los hace cambiar es la cantidad de canciones que tengan del mismo genero
